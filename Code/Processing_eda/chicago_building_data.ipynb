# %%
import pandas as pd
import numpy as np
import re

# %%
dat = pd.read_csv('data/US_CHI_BR_trainingdata.tsv', sep='\t', low_memory=False)

# %%
dat.tail(25)
# Out:
#         Unnamed: 0           COMPLAINT ID            CITY  \
# 281091      232512  US_BATON_ROUGE_383789  US_BATON_ROUGE
# 281092      232513  US_BATON_ROUGE_383790  US_BATON_ROUGE
# 281093      232514  US_BATON_ROUGE_383794  US_BATON_ROUGE
# 281094      232515  US_BATON_ROUGE_383797  US_BATON_ROUGE
# 281095      232516  US_BATON_ROUGE_383792  US_BATON_ROUGE
# 281096      232517  US_BATON_ROUGE_383793  US_BATON_ROUGE
# 281097      232518  US_BATON_ROUGE_383804  US_BATON_ROUGE
# 281098      232519  US_BATON_ROUGE_383800  US_BATON_ROUGE
# 281099      232520  US_BATON_ROUGE_383801  US_BATON_ROUGE
# 281100      232521  US_BATON_ROUGE_383805  US_BATON_ROUGE
# 281101      232522  US_BATON_ROUGE_383807  US_BATON_ROUGE
# 281102      232523  US_BATON_ROUGE_383795  US_BATON_ROUGE
# 281103      232524  US_BATON_ROUGE_383806  US_BATON_ROUGE
# 281104      232525  US_BATON_ROUGE_383798  US_BATON_ROUGE
# 281105      232526  US_BATON_ROUGE_383815  US_BATON_ROUGE
# ...
